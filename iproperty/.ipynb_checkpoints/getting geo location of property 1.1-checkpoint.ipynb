# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
df = pd.read_csv('propsocial2020.csv')
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 0               0             0
# 1               1             1
# 2               2             2
# 3               3             3
# 4               4             4
# ...           ...           ...
# 91524        2360          2360
# 91525        2361          2361
# 91526        2362          2362
# 91527        2363          2363
# 91528        2364          2364
#
#                                                     link  \
# 0      https://www.propsocial.my/developments/taman-l...
# 1      https://www.propsocial.my/developments/taman-s...
# 2      https://www.propsocial.my/developments/bandar-...
# 3                      /developments/uno-promenade-10536
# 4      https://www.propsocial.my/developments/east-le...
# ...                                                  ...
# 91524  https://www.propsocial.my/developments/taman-k...
# 91525  https://www.propsocial.my/developments/mutiara...
# ...

# %%
df = df.rename(columns={'Unnamed: 0': 'index', 'addrress':'address'})

# %%
df
# Out:
#        index  Unnamed: 0.1                                               link  \
# 0          0             0  https://www.propsocial.my/developments/taman-l...
# 1          1             1  https://www.propsocial.my/developments/taman-s...
# 2          2             2  https://www.propsocial.my/developments/bandar-...
# 3          3             3                  /developments/uno-promenade-10536
# 4          4             4  https://www.propsocial.my/developments/east-le...
# ...      ...           ...                                                ...
# 91524   2360          2360  https://www.propsocial.my/developments/taman-k...
# 91525   2361          2361  https://www.propsocial.my/developments/mutiara...
# 91526   2362          2362                        /developments/m-adora-10774
# 91527   2363          2363  https://www.propsocial.my/developments/nadayu-...
# 91528   2364          2364  https://www.propsocial.my/developments/quaysid...
#
# ...

# %%
def locate(df):
    location = locator.geocode(df['address'])
    print("Processing ",df['index'], "out of 91529")
    return location

# %%
locator.geocode('11a jalan krisoberil satu')
#location = locator.geocode(“Champ de Mars, Paris, France”)
# Out:
# Location(Jalan Krisoberil Satu 7/20A, Seksyen 7, Shah Alam, Selangor, 40450, Malaysia, (3.0793034, 101.4967068, 0.0))

# %%
locator = Nominatim(user_agent="myGeocoder")

# 1 - conveneint function to delay between geocoding calls
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)

# 2- - create location column
df['location'] = df.apply(lambda x: locate(x) if x.address else None, axis=1)
# Out:
# Processing  0 out of 91529
# Processing  1 out of 91529
# Processing  2 out of 91529
# Processing  3 out of 91529
# Processing  4 out of 91529
# Processing  5 out of 91529
# Processing  6 out of 91529
# Processing  7 out of 91529
# Processing  8 out of 91529
# Processing  9 out of 91529
# Processing  10 out of 91529
# Processing  11 out of 91529
# Processing  12 out of 91529
# Processing  13 out of 91529
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-a26875477c66> in <module>
#       5
#       6 # 2- - create location column
# ----> 7 df['location'] = df.apply(lambda x: locate(x) if x.address else None, axis=1)
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7545             kwds=kwds,
#    7546         )
# -> 7547         return op.get_result()
#    7548
# ...

# %%
# 3 - create longitude, laatitude and altitude from location column (returns tuple)
df['point'] = df['location'].apply(lambda loc: tuple(loc.point) if loc else None)

# 4 - split point column into latitude, longitude and altitude columns
df[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df['point'].tolist(), index=df.index)

# %%
df.to_csv('propsocial2020_geodata')
