# %%
import pandas as pd

# %%
df = pd.read_csv('propsocial2020.csv')
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 0               0             0
# 1               1             1
# 2               2             2
# 3               3             3
# 4               4             4
# ...           ...           ...
# 91524        2360          2360
# 91525        2361          2361
# 91526        2362          2362
# 91527        2363          2363
# 91528        2364          2364
#
#                                                     link  \
# 0      https://www.propsocial.my/developments/taman-l...
# 1      https://www.propsocial.my/developments/taman-s...
# 2      https://www.propsocial.my/developments/bandar-...
# 3                      /developments/uno-promenade-10536
# 4      https://www.propsocial.my/developments/east-le...
# ...                                                  ...
# 91524  https://www.propsocial.my/developments/taman-k...
# 91525  https://www.propsocial.my/developments/mutiara...
# ...

# %%
df_1 = df.iloc[:10000,:] 
df_2 = df.iloc[10001:20000,:]
df_3 = df.iloc[20001:30000,:]
df_4 = df.iloc[30001:40000,:]
df_5 = df.iloc[40001:50000,:]
df_6 = df.iloc[50001:60000,:]
df_7 = df.iloc[60001:70000,:]
df_8 = df.iloc[70001:80000,:]
df_9 = df.iloc[80001:90000,:]
df_10 = df.iloc[90001:,:]

# %%
df_1
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 0              0             0
# 1              1             1
# 2              2             2
# 3              3             3
# 4              4             4
# ...          ...           ...
# 9995        3457          3457
# 9996        3458          3458
# 9997        3459          3459
# 9998        3460          3460
# 9999        3461          3461
#
#                                                    link  \
# 0     https://www.propsocial.my/developments/taman-l...
# 1     https://www.propsocial.my/developments/taman-s...
# 2     https://www.propsocial.my/developments/bandar-...
# 3                     /developments/uno-promenade-10536
# 4     https://www.propsocial.my/developments/east-le...
# ...                                                 ...
# 9995  https://www.propsocial.my/developments/mahkota...
# 9996  https://www.propsocial.my/developments/taman-k...
# 9997  https://www.propsocial.my/developments/laman-s...
# ...

# %%
df_1.to_csv('propsocial2020_01_hamizah.csv')
df_2.to_csv('propsocial2020_02_hamizah.csv')
df_3.to_csv('propsocial2020_03_hamizah.csv')
df_4.to_csv('propsocial2020_04_faris.csv')
df_5.to_csv('propsocial2020_05_faris.csv')
df_6.to_csv('propsocial2020_06_faris.csv')
df_7.to_csv('propsocial2020_07_nael.csv')
df_8.to_csv('propsocial2020_08_nael.csv')
df_9.to_csv('propsocial2020_09_nael.csv')
df_10.to_csv('propsocial2020_10_nael.csv')

# %%
df_9
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 80001       58988         58988
# 80002       58989         58989
# 80003       58990         58990
# 80004       58991         58991
# 80005       58992         58992
# ...           ...           ...
# 89995         806           806
# 89996         807           807
# 89997         808           808
# 89998         809           809
# 89999         810           810
#
#                                                     link  \
# 80001  https://www.propsocial.my/developments/taman-p...
# 80002  https://www.propsocial.my/developments/segar-c...
# 80003  https://www.propsocial.my/developments/usj-5/4...
# 80004  https://www.propsocial.my/developments/taman-b...
# 80005                        /developments/m-adora-10774
# ...                                                  ...
# 89995  https://www.propsocial.my/developments/kampung...
# 89996  https://www.propsocial.my/developments/conlay/...
# ...

# %%
df_8
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 70001       48988         48988
# 70002       48989         48989
# 70003       48990         48990
# 70004       48991         48991
# 70005       48992         48992
# ...           ...           ...
# 79995       58982         58982
# 79996       58983         58983
# 79997       58984         58984
# 79998       58985         58985
# 79999       58986         58986
#
#                                                     link  \
# 70001  https://www.propsocial.my/developments/taman-s...
# 70002  /developments/precinct-arundina-setia-eco-park...
# 70003  https://www.propsocial.my/developments/sri-cem...
# 70004  https://www.propsocial.my/developments/bukit-t...
# 70005  https://www.propsocial.my/developments/taman-s...
# ...                                                  ...
# 79995  https://www.propsocial.my/developments/almaspu...
# 79996  https://www.propsocial.my/developments/taman-b...
# ...
