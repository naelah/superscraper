# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
df1 = pd.read_csv('propsocial2020_07_nael.csv')
df2 = pd.read_csv('propsocial2020_08_nael.csv')
df3 = pd.read_csv('propsocial2020_09_nael.csv')
df4 = pd.read_csv('propsocial2020_10_nael.csv')
df1
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  \
# 0          60001         38988           38988
# 1          60002         38989           38989
# 2          60003         38990           38990
# 3          60004         38991           38991
# 4          60005         38992           38992
# ...          ...           ...             ...
# 9994       69995         48982           48982
# 9995       69996         48983           48983
# 9996       69997         48984           48984
# 9997       69998         48985           48985
# 9998       69999         48986           48986
#
#                                                    link  \
# 0                           /developments/m-adora-10774
# 1     https://www.propsocial.my/developments/kelisa-...
# 2     https://www.propsocial.my/developments/antara-...
# 3     https://www.propsocial.my/developments/bukit-p...
# 4     https://www.propsocial.my/developments/taman-k...
# ...

# %%
df1 = df1.rename(columns={'Unnamed: 0': 'index', 'addrress':'address'})
df2 = df2.rename(columns={'Unnamed: 0': 'index', 'addrress':'address'})
df3 = df3.rename(columns={'Unnamed: 0': 'index', 'addrress':'address'})

# %%
df4 = df4.rename(columns={'Unnamed: 0': 'index', 'addrress':'address'})

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
def locate(df):
    try:
        location = locator.geocode(df['address'])
    except:
        location = np.nan
    print("Processing ",df['index'], "out of 91529")
    return location

# %%
locator.geocode('11a jalan krisoberil satu')
#location = locator.geocode(“Champ de Mars, Paris, France”)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-712930efa1c3> in <module>
# ----> 1 locator.geocode('11a jalan krisoberil satu')
#       2 #location = locator.geocode(“Champ de Mars, Paris, France”)
#
# NameError: name 'locator' is not defined

# %%
locator = Nominatim(user_agent="myGeocoder")

# 1 - conveneint function to delay between geocoding calls
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)

# 2- - create location column
df1['location'] = df1.apply(lambda x: locate(x) if x.address else None, axis=1)
# Out:
# Processing  60001 out of 91529
# Processing  60002 out of 91529
# Processing  60003 out of 91529
# Processing  60004 out of 91529
# Processing  60005 out of 91529
# Processing  60006 out of 91529
# Processing  60007 out of 91529
# Processing  60008 out of 91529
# Processing  60009 out of 91529
# Processing  60010 out of 91529
# Processing  60011 out of 91529
# Processing  60012 out of 91529
# Processing  60013 out of 91529
# Processing  60014 out of 91529
# Processing  60015 out of 91529
# Processing  60016 out of 91529
# Processing  60017 out of 91529
# Processing  60018 out of 91529
# Processing  60019 out of 91529
# Processing  60020 out of 91529
# Processing  60021 out of 91529
# Processing  60022 out of 91529
# Processing  60023 out of 91529
# Processing  60024 out of 91529
# Processing  60025 out of 91529
# Processing  60026 out of 91529
# Processing  60027 out of 91529
# Processing  60028 out of 91529
# Processing  60029 out of 91529
# Processing  60030 out of 91529
# ...

# %%
locator = Nominatim(user_agent="myGeocoder")

# 1 - conveneint function to delay between geocoding calls
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)

# 2- - create location column
df2['location'] = df2.apply(lambda x: locate(x) if x.address else None, axis=1)
# Out:
# Processing  70001 out of 91529
# Processing  70002 out of 91529
# Processing  70003 out of 91529
# Processing  70004 out of 91529
# Processing  70005 out of 91529
# Processing  70006 out of 91529
# Processing  70007 out of 91529
# Processing  70008 out of 91529
# Processing  70009 out of 91529
# Processing  70010 out of 91529
# Processing  70011 out of 91529
# Processing  70012 out of 91529
# Processing  70013 out of 91529
# Processing  70014 out of 91529
# Processing  70015 out of 91529
# Processing  70016 out of 91529
# Processing  70017 out of 91529
# Processing  70018 out of 91529
# Processing  70019 out of 91529
# Processing  70020 out of 91529
# Processing  70021 out of 91529
# Processing  70022 out of 91529
# Processing  70023 out of 91529
# Processing  70024 out of 91529
# Processing  70025 out of 91529
# Processing  70026 out of 91529
# Processing  70027 out of 91529
# Processing  70028 out of 91529
# Processing  70029 out of 91529
# Processing  70030 out of 91529
# ...

# %%
locator = Nominatim(user_agent="myGeocoder")

# 1 - conveneint function to delay between geocoding calls
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)

# 2- - create location column
df3['location'] = df3.apply(lambda x: locate(x) if x.address else None, axis=1)
# Out:
# Processing  80001 out of 91529
# Processing  80002 out of 91529
# Processing  80003 out of 91529
# Processing  80004 out of 91529
# Processing  80005 out of 91529
# Processing  80006 out of 91529
# Processing  80007 out of 91529
# Processing  80008 out of 91529
# Processing  80009 out of 91529
# Processing  80010 out of 91529
# Processing  80011 out of 91529
# Processing  80012 out of 91529
# Processing  80013 out of 91529
# Processing  80014 out of 91529
# Processing  80015 out of 91529
# Processing  80016 out of 91529
# Processing  80017 out of 91529
# Processing  80018 out of 91529
# Processing  80019 out of 91529
# Processing  80020 out of 91529
# Processing  80021 out of 91529
# Processing  80022 out of 91529
# Processing  80023 out of 91529
# Processing  80024 out of 91529
# Processing  80025 out of 91529
# Processing  80026 out of 91529
# Processing  80027 out of 91529
# Processing  80028 out of 91529
# Processing  80029 out of 91529
# Processing  80030 out of 91529
# ...

# %%
locator = Nominatim(user_agent="myGeocoder")

# 1 - conveneint function to delay between geocoding calls
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)

# 2- - create location column
df4['location'] = df4.apply(lambda x: locate(x) if x.address else None, axis=1)
# Out:
# Processing  90001 out of 91529
# Processing  90002 out of 91529
# Processing  90003 out of 91529
# Processing  90004 out of 91529
# Processing  90005 out of 91529
# Processing  90006 out of 91529
# Processing  90007 out of 91529
# Processing  90008 out of 91529
# Processing  90009 out of 91529
# Processing  90010 out of 91529
# Processing  90011 out of 91529
# Processing  90012 out of 91529
# Processing  90013 out of 91529
# Processing  90014 out of 91529
# Processing  90015 out of 91529
# Processing  90016 out of 91529
# Processing  90017 out of 91529
# Processing  90018 out of 91529
# Processing  90019 out of 91529
# Processing  90020 out of 91529
# Processing  90021 out of 91529
# Processing  90022 out of 91529
# Processing  90023 out of 91529
# Processing  90024 out of 91529
# Processing  90025 out of 91529
# Processing  90026 out of 91529
# Processing  90027 out of 91529
# Processing  90028 out of 91529
# Processing  90029 out of 91529
# Processing  90030 out of 91529
# ...

# %%
# 3 - create longitude, laatitude and altitude from location column (returns tuple)
df1['point'] = df1['location'].apply(lambda loc: tuple(loc.point) if loc else None)

# 4 - split point column into latitude, longitude and altitude columns
df1[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df1['point'].tolist(), index=df1.index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-e796b206d484> in <module>
#       1 # 3 - create longitude, laatitude and altitude from location column (returns tuple)
# ----> 2 df1['point'] = df1['location'].apply(lambda loc: tuple(loc.point) if loc else None)
#       3
#       4 # 4 - split point column into latitude, longitude and altitude columns
#       5 df1[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df1['point'].tolist(), index=df1.index)
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# ...

# %%
# 3 - create longitude, laatitude and altitude from location column (returns tuple)
df2['point'] = df2['location'].apply(lambda loc: tuple(loc.point) if loc else None)

# 4 - split point column into latitude, longitude and altitude columns
df2[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df2['point'].tolist(), index=df2.index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-bbbc5eb174ee> in <module>
#       1 # 3 - create longitude, laatitude and altitude from location column (returns tuple)
# ----> 2 df2['point'] = df2['location'].apply(lambda loc: tuple(loc.point) if loc else None)
#       3
#       4 # 4 - split point column into latitude, longitude and altitude columns
#       5 df2[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df2['point'].tolist(), index=df2.index)
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# ...

# %%
# 3 - create longitude, laatitude and altitude from location column (returns tuple)
df3['point'] = df3['location'].apply(lambda loc: tuple(loc.point) if loc else None)

# 4 - split point column into latitude, longitude and altitude columns
df3[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df3['point'].tolist(), index=df3.index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-f1d05483a837> in <module>
#       1 # 3 - create longitude, laatitude and altitude from location column (returns tuple)
# ----> 2 df3['point'] = df3['location'].apply(lambda loc: tuple(loc.point) if loc else None)
#       3
#       4 # 4 - split point column into latitude, longitude and altitude columns
#       5 df3[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df3['point'].tolist(), index=df3.index)
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# ...

# %%
df1.to_csv('propsocial2020_geodata_07.csv')
df2.to_csv('propsocial2020_geodata_08.csv')
df3.to_csv('propsocial2020_geodata_09.csv')

# %%
df4.to_csv('propsocial2020_geodata_10.csv')

# %%
df1
# Out:
#       index  Unnamed: 0.1  Unnamed: 0.1.1  \
# 0     60001         38988           38988
# 1     60002         38989           38989
# 2     60003         38990           38990
# 3     60004         38991           38991
# 4     60005         38992           38992
# ...     ...           ...             ...
# 9994  69995         48982           48982
# 9995  69996         48983           48983
# 9996  69997         48984           48984
# 9997  69998         48985           48985
# 9998  69999         48986           48986
#
#                                                    link  \
# 0                           /developments/m-adora-10774
# 1     https://www.propsocial.my/developments/kelisa-...
# 2     https://www.propsocial.my/developments/antara-...
# 3     https://www.propsocial.my/developments/bukit-p...
# 4     https://www.propsocial.my/developments/taman-k...
# ...                                                 ...
# 9994  https://www.propsocial.my/developments/menara-...
# ...

# %%
df2
# Out:
#       index  Unnamed: 0.1  Unnamed: 0.1.1  \
# 0     70001         48988           48988
# 1     70002         48989           48989
# 2     70003         48990           48990
# 3     70004         48991           48991
# 4     70005         48992           48992
# ...     ...           ...             ...
# 9994  79995         58982           58982
# 9995  79996         58983           58983
# 9996  79997         58984           58984
# 9997  79998         58985           58985
# 9998  79999         58986           58986
#
#                                                    link  \
# 0     https://www.propsocial.my/developments/taman-s...
# 1     /developments/precinct-arundina-setia-eco-park...
# 2     https://www.propsocial.my/developments/sri-cem...
# 3     https://www.propsocial.my/developments/bukit-t...
# 4     https://www.propsocial.my/developments/taman-s...
# ...                                                 ...
# 9994  https://www.propsocial.my/developments/almaspu...
# ...

# %%
df3
# Out:
#       index  Unnamed: 0.1  Unnamed: 0.1.1  \
# 0     80001         58988           58988
# 1     80002         58989           58989
# 2     80003         58990           58990
# 3     80004         58991           58991
# 4     80005         58992           58992
# ...     ...           ...             ...
# 9994  89995           806             806
# 9995  89996           807             807
# 9996  89997           808             808
# 9997  89998           809             809
# 9998  89999           810             810
#
#                                                    link  \
# 0     https://www.propsocial.my/developments/taman-p...
# 1     https://www.propsocial.my/developments/segar-c...
# 2     https://www.propsocial.my/developments/usj-5/4...
# 3     https://www.propsocial.my/developments/taman-b...
# 4                           /developments/m-adora-10774
# ...                                                 ...
# 9994  https://www.propsocial.my/developments/kampung...
# ...
