# %%
import requests # for web requests
from bs4 import BeautifulSoup # a powerful HTML parser
from selenium.webdriver import Chrome
import pandas as pd # for .csv file read and write
import time 
import numpy as np
import re # for regular regression handling
#from requests_html import HTMLSession
#session = HTMLSession()

headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36'}
path = "/usr/local/Caskroom/chromedriver/86.0.4240.22/chromedriver"
driver = Chrome(executable_path=path)

# %%
#key = 'site:cinema.com.my/movies/details+malay'
base_url = 'https://www.propsocial.my/buy/malaysia-1'
params = {'page': None}

links = list()
titles = list()
details = list()
prices = list()
loaded = True
page = 1

anchors = []
while loaded:
    print('Loading page {} ...'.format(page))
    params['page'] = page
    
    driver.get(base_url+'?page='+str(page))
    #time.sleep(3)
    
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    search_results = soup.find_all('div', {'class': 'classified-ad-details'})
    len(search_results)
    for search_detail in search_results:
        data = search_detail.find_all('div',{'class':'classified-ad-specific-detail'})
        clean_data = list()
        for datum in data:
            clean_data.append(re.sub('\s+',' ',datum.text))
        anchors = search_detail.find_all('a')
        link = anchors[0]['href']
        title = re.sub('\s+',' ',anchors[0].text)
        if len(anchors) > 1:
            price = re.sub('\s+',' ',anchors[1].text)
        else:
            price = np.nan
        
        links.append(link)
        titles.append(title)
        prices.append(price)
        details.append(clean_data)


   
    results = []
            
    if not len(search_results):
        loaded = False
    else:
        #position_links += links
        page += 1
# Out:
# Loading page 1 ...
# Loading page 2 ...
# Loading page 3 ...
# Loading page 4 ...
# Loading page 5 ...
# Loading page 6 ...
# Loading page 7 ...
# Loading page 8 ...
# Loading page 9 ...
# Loading page 10 ...
# Loading page 11 ...
# Loading page 12 ...
# Loading page 13 ...
# Loading page 14 ...
# Loading page 15 ...
# Loading page 16 ...
# Loading page 17 ...
# Loading page 18 ...
# Loading page 19 ...
# Loading page 20 ...
# Loading page 21 ...
# Loading page 22 ...
# Loading page 23 ...
# Loading page 24 ...
# Loading page 25 ...
# Loading page 26 ...
# Loading page 27 ...
# Loading page 28 ...
# Loading page 29 ...
# Loading page 30 ...
# Loading page 31 ...
# Loading page 32 ...
# Loading page 33 ...
# Loading page 34 ...
# Loading page 35 ...
# Loading page 36 ...
# Loading page 37 ...
# Loading page 38 ...
# Loading page 39 ...
# Loading page 40 ...
# Loading page 41 ...
# Loading page 42 ...
# Loading page 43 ...
# Loading page 44 ...
# Loading page 45 ...
# Loading page 46 ...
# Loading page 47 ...
# Loading page 48 ...
# Loading page 49 ...
# Loading page 50 ...
# Loading page 51 ...
# Loading page 52 ...
# Loading page 53 ...
# Loading page 54 ...
# Loading page 55 ...
# Loading page 56 ...
# Loading page 57 ...
# Loading page 58 ...
# Loading page 59 ...
# Loading page 60 ...
# Loading page 61 ...
# Loading page 62 ...
# Loading page 63 ...
# Loading page 64 ...
# Loading page 65 ...
# Loading page 66 ...
# Loading page 67 ...
# Loading page 68 ...
# Loading page 69 ...
# Loading page 70 ...
# Loading page 71 ...
# Loading page 72 ...
# Loading page 73 ...
# Loading page 74 ...
# Loading page 75 ...
# Loading page 76 ...
# Loading page 77 ...
# Loading page 78 ...
# Loading page 494 ...
# Loading page 495 ...
# Loading page 496 ...
# Loading page 497 ...
# Loading page 498 ...
# Loading page 499 ...
# Loading page 500 ...
# Loading page 501 ...
# Loading page 502 ...
# Loading page 503 ...
# Loading page 504 ...
# Loading page 505 ...
# Loading page 506 ...
# Loading page 507 ...
# Loading page 508 ...
# Loading page 509 ...
# Loading page 510 ...
# Loading page 511 ...
# Loading page 512 ...
# Loading page 513 ...
# Loading page 514 ...
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-42-beae4f677503> in <module>
#      15     params['page'] = page
#      16
# ---> 17     driver.get(base_url+'?page='+str(page))
#      18     #time.sleep(3)
#      19
#
# ~/Library/Python/3.8/lib/python/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~/Library/Python/3.8/lib/python/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/Library/Python/3.8/lib/python/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: disconnected: Unable to receive message from renderer
#   (Session info: chrome=86.0.4240.111)

# %%
dict = {'link':links, 'title':titles, 'detail':details}
df = pd.DataFrame(dict)
df
# Out:
#                                                    link  \
# 0     https://www.propsocial.my/developments/bk2/ter...
# 1     https://www.propsocial.my/developments/section...
# 2     https://www.propsocial.my/developments/taman-s...
# 3          /developments/valerian-kundang-estates-10744
# 4     https://www.propsocial.my/developments/casa-re...
# ...                                                 ...
# 8975  https://www.propsocial.my/developments/taman-p...
# 8976  https://www.propsocial.my/developments/jalan-m...
# 8977                /developments/edence-florence-11016
# 8978  https://www.propsocial.my/developments/vilaris...
# 8979  https://www.propsocial.my/developments/taman-s...
#
#                                         title  \
# 0                        BK2, Bandar Kinrara
# 1           Section 6, Bandar Mahkota Cheras
# 2                  Taman Sri Manja, PJ South
# 3                 Valerian @ Kundang Estates
# 4      Casa Residence, Bandar Mahkota Cheras
# ...                                       ...
# 8975              Taman Putra Prima, Puchong
# 8976                   Jalan Maarof, Bangsar
# 8977                       Edence & Florence
# 8978                      Vilaris, Batu Uban
# 8979          Taman Seri Austin, Johor Bahru
#
#                                                  detail
# 0     [ Freehold ,  Terrace ,  2,000 SQ. FT ,  Semi ...
# 1     [ Freehold ,  Terrace ,  1,888 SQ. FT ,  Semi ...
# 2     [ Freehold ,  Condominium ,  1,138 SQ. FT ,  S...
# 3     [ Leasehold ,  Link ,  2,120 SQ. FT ,  Total o...
# 4     [ Freehold ,  Semi Detached ,  3,615 SQ. FT , ...
# ...                                                 ...
# 8975  [ Freehold ,  Semi Detached ,  1,790 SQ. FT , ...
# 8976  [ Freehold ,  Bungalow ,  6,000 SQ. FT ,  Unfu...
# 8977  [ Freehold ,  Semi Detached ,  Sqf not specifi...
# 8978  [ Freehold ,  Terrace ,  3,736 SQ. FT ,  Unfur...
# 8979  [ Freehold ,  Terrace ,  1,949 SQ. FT ,  Semi ...
#
# [8980 rows x 3 columns]

# %%
df.to_csv('1to514price.csv')

# %%
len(titles)
# Out:
# 8980

# %%
len(details)
# Out:
# 8980

# %%
soup
# Out:
# <html class="" lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml"><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# place: http://ogp.me/ns/place#">
# <link href="/manifest.json" rel="manifest"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <script src="https://www.googletagservices.com/activeview/js/current/osd.js?cb=%2Fr20100101"></script><script src="https://partner.googleadservices.com/gampad/cookie.js?domain=www.propsocial.my&amp;callback=_gfp_s_&amp;client=ca-pub-1871661485072379&amp;cookie=ID%3Dd6c0206e4a588fe6-2260e42d82c4005d%3AT%3D1604159847%3ART%3D1604159847%3AS%3DALNI_Mac_X6WHmarM2-BzKBBfipOgEsyYA"></script><script id="google_shimpl" src="https://pagead2.googlesyndication.com/pagead/js/r20201029/r20190131/show_ads_impl_fy2019.js"></script><script async="" crossorigin="anonymous" src="https://connect.facebook.net/en_US/sdk.js?hash=8cf1550c416ac47ed67de98daf09edf4&amp;ua=modern_es6"></script><script async="" src="https://www.google-analytics.com/plugins/ua/linkid.js" type="text/javascript"></script><script id="twitter-wjs" src="https://platform.twitter.com/widgets.js"></script><script async="" src="https://connect.facebook.net/signals/config/2007555396232641?v=2.9.27&amp;r=stable"></script><script id="facebook-jssdk" src="//connect.facebook.net/en_US/sdk.js#xfbml=1&amp;appId=512104078923535&amp;version=v2.0"></script><script async="" src="https://cdn.userreport.com/userreport.js" type="text/javascript"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script>window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"7028853a9b","applicationID":"5596135","transactionName":"dQlfRxBaVFwEExtVXlcVQloEXF1UPgBQRR1fCFVWGg==","queueTime":0,"applicationTime":1691,"agent":""}</script>
# <script>(window.NREUM||(NREUM={})).loader_config={licenseKey:"7028853a9b",applicationID:"5596135"};window.NREUM||(NREUM={}),__nr_require=function(e,t,n){function r(n){if(!t[n]){var i=t[n]={exports:{}};e[n][0].call(i.exports,function(t){var i=e[n][1][t];return r(i||t)},i,i.exports)}return t[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(e,t,n){function r(){}function i(e,t,n){return function(){return o(e,[u.now()].concat(c(arguments)),t?null:this,n),t?void 0:this}}var o=e("handle"),a=e(6),c=e(7),f=e("ee").get("tracer"),u=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var d=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],p="api-",l=p+"ixn-";a(d,function(e,t){s[t]=i(p+t,!0,"api")}),s.addPageAction=i(p+"addPageAction",!0),s.setCurrentRouteName=i(p+"routeName",!0),t.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,t){var n={},r=this,i="function"==typeof t;return o(l+"tracer",[u.now(),e,n],r),function(){if(f.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return t.apply(this,arguments)}catch(e){throw f.emit("fn-err",[arguments,this,e],n),e}finally{f.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,t){m[t]=i(l+t)}),newrelic.noticeError=function(e,t){"string"==typeof e&&(e=new Error(e)),o("err",[e,u.now(),!1,t])}},{}],2:[function(e,t,n){function r(){return c.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,c=e(8);t.exports=r,t.exports.offset=a,t.exports.getLastTimestamp=i},{}],3:[function(e,t,n){function r(e,t){var n=e.getEntries();n.forEach(function(e){"first-paint"===e.name?d("timing",["fp",Math.floor(e.startTime)]):"first-contentful-paint"===e.name&&d("timing",["fcp",Math.floor(e.startTime)])})}function i(e,t){var n=e.getEntries();n.length>0&&d("lcp",[n[n.length-1]])}function o(e){e.getEntries().forEach(function(e){e.hadRecentInput||d("cls",[e])})}function a(e){if(e instanceof m&&!g){var t=Math.round(e.timeStamp),n={type:e.type};t<=p.now()?n.fid=p.now()-t:t>p.offset&&t<=Date.now()?(t-=p.offset,n.fid=p.now()-t):t=p.now(),g=!0,d("timing",["fi",t,n])}}function c(e){d("pageHide",[p.now(),e])}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var f,u,s,d=e("handle"),p=e("loader"),l=e(5),m=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){f=new PerformanceObserver(r);try{f.observe({entryTypes:["paint"]})}catch(v){}u=new PerformanceObserver(i);try{u.observe({entryTypes:["largest-contentful-paint"]})}catch(v){}s=new PerformanceObserver(o);try{s.observe({type:"layout-shift",buffered:!0})}catch(v){}}if("addEventListener"in document){var g=!1,y=["click","keydown","mousedown","pointerdown","touchstart"];y.forEach(function(e){document.addEventListener(e,a,!1)})}l(c)}},{}],4:[function(e,t,n){function r(e,t){if(!i)return!1;if(e!==i)return!1;if(!t)return!0;if(!o)return!1;for(var n=o.split("."),r=t.split("."),a=0;a<r.length;a++)if(r[a]!==n[a])return!1;return!0}var i=null,o=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var c=navigator.userAgent,f=c.match(a);f&&c.indexOf("Chrome")===-1&&c.indexOf("Chromium")===-1&&(i="Safari",o=f[1])}t.exports={agent:i,version:o,match:r}},{}],5:[function(e,t,n){function r(e){function t(){e(a&&document[a]?document[a]:document[i]?"hidden":"visible")}"addEventListener"in document&&o&&document.addEventListener(o,t,!1)}t.exports=r;var i,o,a;"undefined"!=typeof document.hidden?(i="hidden",o="visibilitychange",a="visibilityState"):"undefined"!=typeof document.msHidden?(i="msHidden",o="msvisibilitychange"):"undefined"!=typeof document.webkitHidden&&(i="webkitHidden",o="webkitvisibilitychange",a="webk ...
# <meta content="MC9DfdsoKScaT7qozOGF-AXciyizngv8qQY0mXQj9DY" name="google-site-verification"/>
# <meta content="gpMiN9-7nFPyh_raMs0Uy3ovwmoXsBafN_jjCUGdrTY" name="google-site-verification"/>
# <meta content="op19cggnqBqMHvI7O7NpgsIIwCtUPn8Wzsy4CYHT0eg" name="google-site-verification"/>
# <link href="https://plus.google.com/+PropsocialMy" rel="publisher"/>
# <meta content="F8B068C2667A4BB821E3FAEA7235E011" name="msvalidate.01"/>
# <link href="https://d19b02hn5tml7l.cloudfront.net/assets/application-a0ba18cd66cf1c2f05e3615697dd11d5.css" media="all" rel="stylesheet"/>
# <!-- Google Fonts Roboto -->
# <link href="https://fonts.googleapis.com/css?family=Roboto:400,100,300,300italic,100italic,400italic,500,500italic,700,700italic,900,900italic" media="screen" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Inconsolata" media="screen" rel="stylesheet"/>
# <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css" media="all" rel="stylesheet"/>
# <title>Property For Sale in Malaysia (Page 339) | PropSocial</title>
# <meta content="Find out everything you need to know about Malaysia including condominiums, apartments, bungalows, houses, soho and offices, property buy, pricing information and more. (page 339)" name="description"/>
# <link href="https://d19b02hn5tml7l.cloudfront.net/assets/favicon/apple-touch-icon-57x57-31c18574275d32c0750973e3f9d66823.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://d19b02hn5tml7l.cloudfront.net/assets/favicon/apple-touch-icon-114x114-3fb3088cecf06ae686fd6920bcf7c130.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://d19b02hn5tml7l.cloudfront.net/assets/favicon/apple-touch-icon-72x72-cd3457c7e5acce219cb73860249f4fcf.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://d19b02hn5tml7l.cloudfront.net/assets/favicon/apple-touch-icon-144x144-307443b1c002cb19578ef69862b10195.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://d19b02hn5tml7l.cloudfront.net/assets/favicon/apple-touch-icon-60x60-fe3954a0ea69dbf3513998c7573138c3.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="https://d19b02hn5tml7l.cloudfront.net/assets/favicon/apple-touch-icon-120x120-9c4aefb93d5c7033bccb18540b1f3363.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://d19b02hn5tml7l.cloudfront.net/assets/favicon/apple-touch-icon-76x76-400b54f8f10d4ab17856112d50b2fd18.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://d19b02hn5tml7l.cloudfront.net/assets/favicon/apple-touch-icon-152x152-b5c5bb0f9e7d1dadcf1fbb442543c943.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://d19b02hn5tml7l.cloudfront.net/assets/favicon/apple-touch-icon-180x180-ecd54968fb1030c0bfe0cb11157f801c.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://d19b02hn5tml7l.cloudfront.net/assets/favicon/favicon-192x192-ede32d6a6c0d3893e7cae7d6f84e062e.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="https://d19b02hn5tml7l.cloudfront.net/assets/favicon/favicon-160x160-9e050d7cbcf1187fb10867748bbbbc46.png" rel="icon" sizes="160x160" type="image/png"/>
# <link href="https://d19b02hn5tml7l.cloudfront.net/assets/favicon/favicon-96x96-f14c1263150d13d95bf29a464f43cd9b.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="https://d19b02hn5tml7l.cloudfront.net/assets/favicon/favicon-16x16-10ce623989067c22b21d670751151374.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://d19b02hn5tml7l.cloudfront.net/assets/favicon/favicon-32x32-100444137980964cb0b6dab36be45b91.png" rel="icon" sizes="32x32" type="image/png"/>
# <meta content="#da532c" name="msapplication-TileColor"/>
# <meta content="https://d19b02hn5tml7l.cloudfront.net/assets/favicon/mstile-144x144-307443b1c002cb19578ef69862b10195.png" name="msapplication-TileImage"/>
# <!-- Facebook Pixel Code -->
# <script>
#     !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#     n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];
#     s.parentNode.insertBefore(t,s)}(window, document,'script',
#     'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '2007555396232641');
#     fbq('track', 'PageView');
#   </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=2007555396232641&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="od5tzhW0oJ1VnyZru7iCjQDU27gmXaqgWKrW2YIKMpPH6zWIm9ejD9TGpC/0YFmfTxJnckgokDX1c/YKJye02w==" name="csrf-token"/>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <!-- <script async src="https://www.googletagmanager.com/gtag/js?id=UA-55634528-1"></script>
#   <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#
#     gtag('config', 'UA-55634528-1');
#   </script> -->
# <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-55634528-1', 'auto');
#     ga('require', 'linkid', 'linkid.js');
#     ga('require', 'displayfeatures');
#     ga('send', 'pageview');
#
#     // var trackOutboundLink = function(url) {
#     //   ga('send', 'event', 'footer-link', 'click', url, 'hitCallback');
#     // }
#
#     var trackTopicBannerLink = function(url) {
#       ga('send', 'event', 'topic-banner-link', 'click', url, {'hitCallback':
#         function () {
#           document.location = url;
#         }
#       });
#     }
#     </script>
# <!-- UserReport -->
# <script type="text/javascript">
#       var _urq = _urq || [];
#       _urq.push(['setGACode', 'UA-55634528-1']);
#       _urq.push(['initSite', '3058a9a2-a8ae-4bce-af17-07f757a17d1b']);
#
#       (function() {
#       var ur = document.createElement('script'); ur.type = 'text/javascript'; ur.async = true;
#       ur.src = ('https:' == document.location.protocol ? 'https://cdn.userreport.com/userreport.js' : 'http://cdn.userreport.com/userreport.js');
#       var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ur, s);
#       })();
#
#
#       </script>
# <!-- Trovit Conversion Code -->
# <!-- Adsense -->
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script>
#     (adsbygoogle = window.adsbygoogle || []).push({
#       google_ad_client: "ca-pub-1871661485072379",
#       enable_page_level_ads: true
#     });
#   </script>
# <script async="" charset="utf-8" class="lazyload" src="https://cdn.userreport.com/w_3058a9a2-a8ae-4bce-af17-07f757a17d1b/settings.js"></script><link as="script" href="https://adservice.google.com.my/adsid/integrator.js?domain=www.propsocial.my" rel="preload"/><script src="https://adservice.google.com.my/adsid/integrator.js?domain=www.propsocial.my" type="text/javascript"></script><link as="script" href="https://adservice.google.com/adsid/integrator.js?domain=www.propsocial.my" rel="preload"/><script src="https://adservice.google.com/adsid/integrator.js?domain=www.propsocial.my" type="text/javascript"></script></head>
# <body>
# <div data-lang="" id="body-wrapper">
# <div id="fb-root"></div>
# <script>
# (function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&appId=512104078923535&version=v2.0";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
# </script>
# <script>
# window.twttr = (function (d, s, id) {
#   var t, js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src= "https://platform.twitter.com/widgets.js";
#   fjs.parentNode.insertBefore(js, fjs);
#   return window.twttr || (t = { _e: [], ready: function (f) { t._e.push(f) } });
# }(document, "script", "twitter-wjs"));
# </script>
# <script>
#   window.___gcfg = {
#     lang: 'en-US',
#     parsetags: 'onload'
#   };
# </script>
# <!-- <script src="https://apis.google.com/js/platform.js" async defer></script> -->
# <span id="user-not-logged-in"></span>
# <header>
# <div class="wrap">
# <nav class="navbar navbar-default" role="navigation">
# <div class="container-fluid">
# <div class="navbar-header">
# <a class="navbar-brand" href="/">
# <img alt="Propsocial Logo" class="propsocial-logo" data-original="https://d19b02hn5tml7l.cloudfront.net/assets/logo-22e629a1032f1a52db65d2dd79493852.png" src="/public_assets/images/transparent.png"/>
# </a>
# <button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <div class="collapse navbar-collapse" style="padding-bottom: 10px;">
# <ul class="nav navbar-nav navbar-right" style="padding-top: 15px;">
# <li>
# <a class="pr-btn btn-lightred" href="/property/post-requirements?utm_campaign=pr&amp;utm_medium=header&amp;utm_source=propsocial">
#                 Post Your Requirements
# </a> </li>
# <li id="signup-btn-li">
# <a class="sign-up-btn" href="/users/sign_up">
#                   Sign Up
# </a> </li>
# <li class="login dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#                   Log In
# </a>
#                 &lt;div id="login-header-form" ,="" class="dropdown-menu" role="menu"&gt;
#                   <p class="fs18 text-center fw300">Log in or
#                     <a href="/users/sign_up">Sign Up</a>
# </p>
# <form accept-charset="UTF-8" action="/users/sign_in" class="new_user" id="login-form" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="+PcKUWu5cqA8hfuRCjEugx2y/ksgb7KWe8O4F+y6u+qewlIX5dpxMr3cedVF6fWRUnRCgU4aiAPWGpjESZc9og=="/>
# <input autofocus="autofocus" id="user_email" name="user[email]" placeholder="Email" type="email" value=""/>
# <input autocomplete="off" id="user_password" name="user[password]" placeholder="************" type="password"/>
# <input name="commit" type="submit" value="LOGIN"/>
# <a href="/users/password/new">
# <img alt="Ask" data-original="https://d19b02hn5tml7l.cloudfront.net/assets/ask-ebbd21645b2d619f665f8d28c9642850.png" src="/public_assets/images/transparent.png"/> Forgot Password?
# </a></form>
# <a class="btn btn-facebook connectfb" href="/users/auth/facebook">
# <i class="icon icon-facebook fs16"></i>  Login with Facebook
# </a>
# <a class="btn btn-twitter connecttw" href="/users/auth/twitter">
# <i class="icon icon-twitter fs16"></i>  Login with Twitter
# </a> </li></ul></div>
#
# <li class="mobile-link">
# <a href="/users/sign_in">Log In</a>
# </li>
#
# </div><!-- /.navbar-collapse -->
# <div class="collapse navbar-collapse">
# <ul class="nav second-nav navbar-nav">
# <li>
# <a href="/buy/malaysia-1">Buy</a>
# </li>
# <li>
# <a href="/rent/malaysia-1">Rent</a>
# </li>
# <li>
# <a href="/buy/malaysia-1/upcoming-developments">New Launches</a>
# </li>
# <li>
# <a href="/location/1/malaysia/property-agents">Find Agent</a>
# </li>
# <li>
# <a href="/properties/compare">Compare Properties</a>
# </li>
# <li>
# <a href="/discussions/top">Discussions</a>
# </li>
# <li>
# <a href="/service-products/home-services">Home Products</a>
# </li>
# <li>
# <a class="black" href="/rewards">Rewards</a>
# </li>
# </ul>
# </div><!-- /.navbar-collapse -->
# </nav></div><!-- /.container-fluid -->
#
# </header></div>
#
# <div id="flash">
# </div>
# <section class="inner-search-filter" id="search-filter">
# <div class="wrap">
# <form accept-charset="UTF-8" action="/search" id="advance-search-form" method="get"><input name="utf8" type="hidden" value="✓"/>
# <div class="search-filters-div">
# <div id="inner-search-form">
# <div class="form-horizontal wide-search-form">
# <div class="col-md-12 col-xs-12">
# <div class="input-group">
# <div class="input-group-btn">
# <button aria-expanded="false" aria-haspopup="true" class="btn btn-default dropdown-toggle" data-toggle="dropdown" id="search-selection" type="button">
# <span id="selected-search-option-txt">Buy</span>
# <span class="caret"></span>
# </button>
# <ul class="dropdown-menu search-selection-dropdown">
# <li data-brief="Search For Sale listings within " data-selection="for-sale">
# <a href="#">Buy</a>
# </li>
# <li data-brief="Search For Rent listings within " data-selection="for-rent">
# <a href="#">Rent</a>
# </li>
# <li data-brief="Search for Neighbourhood &amp; Property Info of " data-selection="reviews">
# <a href="#">Reviews &amp; Info</a>
# </li>
# <li class="home-search-selection" data-selection="all-properties">
# <a href="#">New Launches</a>
# </li>
# <li data-brief="Search for REA within " data-selection="agents">
# <a href="#">Real Estate Agents</a>
# </li>
# <li data-brief="Search for Events within " data-selection="events">
# <a href="#">Events</a>
# </li>
# <li data-brief="Search for Discussions within " data-selection="discussions">
# <a href="#">Discussions</a>
# </li>
# </ul>
# <input id="search_selection" name="search_selection" type="hidden" value="for-sale"/>
# </div>
# <input class="form-control input-lg ps-form large border-btm-0 ui-autocomplete-input" id="search-box" name="tag" placeholder="Search for a location or property" type="text" value=""/>
# <span class="input-group-addon" id="home-search-btn-addon">
# <button class="btn btn-darkblue no-shadow" name="button" type="submit">
#               Search   <i class="fa fa-search white" id="search-icon"></i>
# <i class="fa fa-refresh fa-spin fa-lg" id="search-spinner-icon" style="display:none;"></i>
# </button> </span>
# </div>
# <a class="trigger-advance-search inner-trigger-advance-search-link" href="#">
#           Advanced Search
#           <i class="fa fa-sort-up"></i>
# </a> </div>
# </div>
# <div class="clearfix"></div>
# </div>
# <section id="inner-extra-filters-div" style="display: none;">
# <div class="col-xs-12 col-sm-12 col-md-12 nopadding filter-div">
# <div class="col-xs-12 col-sm-12 col-md-4">
# <div class="filter-title">Categories</div>
# <select class="selectpicker show-menu-arrow" data-selected-text-format="count&gt;3" data-width="100%" multiple="" name="category[]" title="Choose categories">
# <optgroup label="Residential">
# <option value="Condominium">Condominium</option>
# <option value="Apartment">Apartment</option>
# <option value="Bungalow">Bungalow</option>
# <option value="Semi-Detached">Semi-Detached</option>
# <option value="Townhouse">Townhouse</option>
# <option value="Terrace">Terrace</option>
# </optgroup>
# <optgroup label="Commercial">
# <option value="Office">Office</option>
# <option value="Shop">Shop</option>
# <option value="Factory">Factory</option>
# </optgroup>
# <optgroup label="Residential / Commercial">
# <option value="Serviced Residence">Serviced Residence</option>
# <option value="Soho/Studio">Soho/Studio</option>
# <option value="Duplex">Duplex</option>
# <option value="Link">Link</option>
# <option value="Superlink">Superlink</option>
# <option value="Villa">Villa</option>
# <option value="Land">Land</option>
# </optgroup>
# </select>
# </div>
# <div id="search-filter-forsale-div">
# <div class="col-xs-12 col-sm-6 col-md-6" id="sale-tenure-div">
# <div class="filter-title">Tenure</div>
# <label class="checkbox-inline">
# <input id="tenure_" name="tenure[]" type="checkbox" value="leasehold"/>
#     Leasehold
#   </label>
# <label class="checkbox-inline">
# <input id="tenure_" name="tenure[]" type="checkbox" value="freehold"/>
#     Freehold
#   </label>
# </div>
# <div class="col-xs-12 col-sm-12 col-md-12 nopadding filter-single-div filter-selects-div">
# <div class="col-xs-12 col-sm-8 col-md-8">
# <div class="col-xs-6 col-sm-6 col-md-6 nopadding">
# <div class="filter-select-div">
# <div class="filter-title">Price Min</div>
# <select class="form-control" id="price_min" name="price_min"><option value="">Select Min</option><option value="0">RM 0</option>
# <option value="100000">RM 100k</option>
# <option value="200000">RM 200k</option>
# <option value="300000">RM 300k</option>
# <option value="400000">RM 400k</option>
# <option value="500000">RM 500k</option>
# <option value="600000">RM 600k</option>
# <option value="800000">RM 800k</option>
# <option value="1000000">RM 1m</option>
# <option value="1500000">RM 1.5m</option>
# <option value="2000000">RM 2m</option>
# <option value="3000000">RM 3m</option></select>
# </div>
# </div>
# <div class="col-xs-6 col-sm-6 col-md-6 nopadding">
# <div class="filter-select-div">
# <div class="filter-title">Price Max</div>
# <select class="form-control" id="price_max" name="price_max"><option value="">Select Max</option><option value="100000">RM 100k</option>
# <option value="200000">RM 200k</option>
# <option value="300000">RM 300k</option>
# <option value="400000">RM 400k</option>
# <option value="500000">RM 500k</option>
# <option value="600000">RM 600k</option>
# <option value="800000">RM 800k</option>
# <option value="1000000">RM 1m</option>
# <option value="1500000">RM 1.5m</option>
# <option value="2000000">RM 2m</option>
# <option value="3000000">RM 3m</option>
# <option value="99000000">Above RM 3m</option></select>
# </div>
# </div>
# <div class="col-xs-6 col-sm-6 col-md-6 nopadding">
# <div class="filter-select-div">
# <div class="filter-title">Build-Up / Size Min</div>
# <select class="form-control" id="size_min" name="size_min"><option value="">Select Min</option><option value="0">0 sq ft</option>
# <option value="100">100 sq ft</option>
# <option value="300">300 sq ft</option>
# <option value="500">500 sq ft</option>
# <option value="700">700 sq ft</option>
# <option value="900">900 sq ft</option>
# <option value="1200">1.2k sq ft</option>
# <option value="1500">1.5k sq ft</option>
# <option value="2000">2k sq ft</option>
# <option value="5000">5k sq ft</option>
# <option value="10000">10k sq ft</option>
# <option value="20000">20k sq ft</option></select>
# </div>
# </div>
# <div class="col-xs-6 col-sm-6 col-md-6 nopadding">
# <div class="filter-select-div">
# <div class="filter-title">Build-Up / Size Max</div>
# <select class="form-control" id="size_max" name="size_max"><option value="">Select Max</option><option value="100">100 sq ft</option>
# <option value="300">300 sq ft</option>
# <option value="500">500 sq ft</option>
# <option value="700">700 sq ft</option>
# <option value="900">900 sq ft</option>
# <option value="1200">1.2k sq ft</option>
# <option value="1500">1.5k sq ft</option>
# <option value="2000">2k sq ft</option>
# <option value="5000">5k sq ft</option>
# <option value="10000">10k sq ft</option>
# <option value="20000">20k sq ft</option>
# <option value="999999">Above 20k sq ft </option></select>
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-4 col-md-4">
# <div class="col-xs-6 col-sm-6 col-md-6 nopadding">
# <div class="filter-select-div">
# <div class="filter-title">Bedroom Min</div>
# <select class="form-control" id="bed_min" name="bed_min"><option value="">Select Min</option><option value="0">0</option>
# <option value="1">1</option>
# <option value="2">2</option>
# <option value="3">3</option>
# <option value="4">4</option>
# <option value="5">5</option>
# <option value="6">6</option>
# <option value="7">7</option>
# <option value="8">8</option>
# <option value="9">9</option>
# <option value="10">10</option>
# <option value="50">10+</option></select>
# </div>
# </div>
# <div class="col-xs-6 col-sm-6 col-md-6 nopadding">
# <div class="filter-select-div">
# <div class="filter-title">Bedroom Max</div>
# <select class="form-control" id="bed_max" name="bed_max"><option value="">Select Max</option><option value="1">1</option>
# <option value="2">2</option>
# <option value="3">3</option>
# <option value="4">4</option>
# <option value="5">5</option>
# <option value="6">6</option>
# <option value="7">7</option>
# <option value="8">8</option>
# <option value="9">9</option>
# <option value="10">10</option>
# <option value="50">10+</option></select>
# </div>
# </div>
# <div class="col-xs-6 col-sm-6 col-md-6 nopadding">
# <div class="filter-select-div">
# <div class="filter-title">Bathroom Min</div>
# <select class="form-control" id="bath_min" name="bath_min"><option value="">Select Min</option><option value="0">0</option>
# <option value="1">1</option>
# <option value="2">2</option>
# <option value="3">3</option>
# <option value="4">4</option>
# <option value="5">5</option>
# <option value="6">6</option>
# <option value="7">7</option>
# <option value="8">8</option>
# <option value="9">9</option>
# <option value="10">10</option>
# <option value="50">10+</option></select>
# </div>
# </div>
# <div class="col-xs-6 col-sm-6 col-md-6 nopadding">
# <div class="filter-select-div">
# <div class="filter-title">Bathroom Max</div>
# <select class="form-control" id="bath_max" name="bath_max"><option value="">Select Max</option><option value="1">1</option>
# <option value="2">2</option>
# <option value="3">3</option>
# <option value="4">4</option>
# <option value="5">5</option>
# <option value="6">6</option>
# <option value="7">7</option>
# <option value="8">8</option>
# <option value="9">9</option>
# <option value="10">10</option>
# <option value="50">10+</option></select>
# </div>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="col-xs-12 col-sm-12 col-md-12 nopadding filter-single-div">
# <div class="col-xs-12 col-sm-6 col-md-6">
# <div class="filter-title">Furnishing</div>
# <label class="checkbox-inline">
# <input id="furnishing_" name="furnishing[]" type="checkbox" value="unfurnished"/>
#       Unfurnished
#     </label>
# <label class="checkbox-inline">
# <input id="furnishing_" name="furnishing[]" type="checkbox" value="semi-furnished"/>
#       Semi-Furnished
#     </label>
# <label class="checkbox-inline">
# <input id="furnishing_" name="furnishing[]" type="checkbox" value="fully-furnished"/>
#       Fully-Furnished
#     </label>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-6">
# <div class="filter-title">Auction</div>
# <label class="checkbox-inline">
# <input id="auction" name="auction" type="checkbox" value="true"/>
#       Only Auction Listings
#     </label>
# </div>
# <!--   <div class="col-xs-12 col-sm-6 col-md-6">
#     <div class='filter-title'>Listing Period</div>
#
#     <label class="radio-inline">
#       <input type="radio" name="period" id="period_3" value="3" />
#       Last 3 Months
#     </label>
#     <label class="radio-inline">
#       <input type="radio" name="period" id="period_6" value="6" />
#       Last 6 Months
#     </label>
#   </div> -->
# </div>
# <div class="clearfix"></div>
# </div>
# <div id="search-filter-forrent-div">
# <div class="col-xs-12 col-sm-6 col-md-6">
# <div class="filter-title">Type</div>
# <label class="checkbox-inline">
# <input id="rent_type_" name="rent_type[]" type="checkbox" value="entire"/>
#     Entire Unit
#   </label>
# <label class="checkbox-inline">
# <input id="rent_type_" name="rent_type[]" type="checkbox" value="room"/>
#     Room Only
#   </label>
# </div>
# <div class="col-xs-12 col-sm-12 col-md-12 nopadding filter-single-div filter-selects-div">
# <div class="col-xs-6 col-sm-4 col-md-4">
# <div class="filter-select-div">
# <div class="filter-title">Price Min</div>
# <select class="form-control" id="price_min" name="price_min"><option value="">Select Min</option><option value="0">RM 0</option>
# <option value="100">RM 100</option>
# <option value="300">RM 300</option>
# <option value="500">RM 500</option>
# <option value="700">RM 700</option>
# <option value="900">RM 900</option>
# <option value="1200">RM 1.2k</option>
# <option value="1500">RM 1.5k</option>
# <option value="2000">RM 2k</option>
# <option value="4000">RM 4k</option>
# <option value="6000">RM 6k</option></select>
# </div>
# <div class="filter-select-div">
# <div class="filter-title">Price Max</div>
# <select class="form-control" id="price_max" name="price_max"><option value="">Select Max</option><option value="100">RM 100</option>
# <option value="300">RM 300</option>
# <option value="500">RM 500</option>
# <option value="700">RM 700</option>
# <option value="900">RM 900</option>
# <option value="1200">RM 1.2k</option>
# <option value="1500">RM 1.5k</option>
# <option value="2000">RM 2k</option>
# <option value="4000">RM 4k</option>
# <option value="6000">RM 6k</option>
# <option value="100000">Above RM 6k</option></select>
# </div>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-4">
# <div class="filter-select-div">
# <div class="filter-title">Build-Up / Size Min</div>
# <select class="form-control" id="size_min" name="size_min"><option value="">Select Min</option><option value="0">0 sq ft</option>
# <option value="100">100 sq ft</option>
# <option value="300">300 sq ft</option>
# <option value="500">500 sq ft</option>
# <option value="700">700 sq ft</option>
# <option value="900">900 sq ft</option>
# <option value="1200">1.2k sq ft</option>
# <option value="1500">1.5k sq ft</option>
# <option value="2000">2k sq ft</option>
# <option value="5000">5k sq ft</option>
# <option value="10000">10k sq ft</option>
# <option value="20000">20k sq ft</option></select>
# </div>
# <div class="filter-select-div">
# <div class="filter-title">Build-Up / Size Max</div>
# <select class="form-control" id="size_max" name="size_max"><option value="">Select Max</option><option value="100">100 sq ft</option>
# <option value="300">300 sq ft</option>
# <option value="500">500 sq ft</option>
# <option value="700">700 sq ft</option>
# <option value="900">900 sq ft</option>
# <option value="1200">1.2k sq ft</option>
# <option value="1500">1.5k sq ft</option>
# <option value="2000">2k sq ft</option>
# <option value="5000">5k sq ft</option>
# <option value="10000">10k sq ft</option>
# <option value="20000">20k sq ft</option>
# <option value="999999">Above 20k sq ft </option></select>
# </div>
# </div>
# <div class="col-xs-6 col-sm-2 col-md-2">
# <div class="filter-select-div">
# <div class="filter-title">Bedroom Min</div>
# <select class="form-control" id="bed_min" name="bed_min"><option value="">Select Min</option><option value="0">0</option>
# <option value="1">1</option>
# <option value="2">2</option>
# <option value="3">3</option>
# <option value="4">4</option>
# <option value="5">5</option>
# <option value="6">6</option>
# <option value="7">7</option>
# <option value="8">8</option>
# <option value="9">9</option>
# <option value="10">10</option>
# <option value="50">10+</option></select>
# </div>
# <div class="filter-select-div">
# <div class="filter-title">Bedroom Max</div>
# <select class="form-control" id="bed_max" name="bed_max"><option value="">Select Max</option><option value="1">1</option>
# <option value="2">2</option>
# <option value="3">3</option>
# <option value="4">4</option>
# <option value="5">5</option>
# <option value="6">6</option>
# <option value="7">7</option>
# <option value="8">8</option>
# <option value="9">9</option>
# <option value="10">10</option>
# <option value="50">10+</option></select>
# </div>
# </div>
# <div class="col-xs-6 col-sm-2 col-md-2">
# <div class="filter-select-div">
# <div class="filter-title">Bathroom Min</div>
# <select class="form-control" id="bath_min" name="bath_min"><option value="">Select Min</option><option value="0">0</option>
# <option value="1">1</option>
# <option value="2">2</option>
# <option value="3">3</option>
# <option value="4">4</option>
# <option value="5">5</option>
# <option value="6">6</option>
# <option value="7">7</option>
# <option value="8">8</option>
# <option value="9">9</option>
# <option value="10">10</option>
# <option value="50">10+</option></select>
# </div>
# <div class="filter-select-div">
# <div class="filter-title">Bathroom Max</div>
# <select class="form-control" id="bath_max" name="bath_max"><option value="">Select Max</option><option value="1">1</option>
# <option value="2">2</option>
# <option value="3">3</option>
# <option value="4">4</option>
# <option value="5">5</option>
# <option value="6">6</option>
# <option value="7">7</option>
# <option value="8">8</option>
# <option value="9">9</option>
# <option value="10">10</option>
# <option value="50">10+</option></select>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="col-xs-12 col-sm-12 col-md-12 nopadding filter-single-div">
# <div class="col-xs-12 col-sm-6 col-md-6">
# <div class="filter-title">Furnishing</div>
# <label class="checkbox-inline">
# <input id="furnishing_" name="furnishing[]" type="checkbox" value="unfurnished"/>
#       Unfurnished
#     </label>
# <label class="checkbox-inline">
# <input id="furnishing_" name="furnishing[]" type="checkbox" value="semi-furnished"/>
#       Semi-Furnished
#     </label>
# <label class="checkbox-inline">
# <input id="furnishing_" name="furnishing[]" type="checkbox" value="fully-furnished"/>
#       Fully-Furnished
#     </label>
# </div>
# <!-- <div class="col-xs-12 col-sm-6 col-md-6">
#     <div class='filter-title'>Listing Period</div>
#     <label class="radio-inline">
#       <input type="radio" name="period" id="period_3" value="3" />
#       Last 3 Months
#     </label>
#     <label class="radio-inline">
#       <input type="radio" name="period" id="period_6" value="6" />
#       Last 6 Months
#     </label>
#   </div> -->
# </div>
# <div class="clearfix"></div>
# </div>
# <div id="search-filter-properties-div">
# <div class="col-xs-12 col-sm-8 col-md-4">
# <div class="filter-title">Tenure</div>
# <label class="checkbox-inline">
# <input id="tenure_" name="tenure[]" type="checkbox" value="leasehold"/>
#     Leasehold
#   </label>
# <label class="checkbox-inline">
# <input id="tenure_" name="tenure[]" type="checkbox" value="freehold"/>
#     Freehold
#   </label>
# </div>
# <div class="col-xs-12 col-sm-8 col-md-4">
# <div class="filter-title">Land Title</div>
# <label class="checkbox-inline">
# <input id="landtitle_" name="landtitle[]" type="checkbox" value="residential"/>
#     Residential
#   </label>
# <label class="checkbox-inline">
# <input id="landtitle_" name="landtitle[]" type="checkbox" value="commercial"/>
#     Commercial
#   </label>
# <label class="checkbox-inline">
# <input id="landtitle_" name="landtitle[]" type="checkbox" value="mixed"/>
#     Mixed
#   </label>
# </div>
# <div class="col-xs-12 col-sm-12 col-md-12 nopadding filter-single-div filter-selects-div">
# <div class="col-xs-12 col-sm-4 col-md-4">
# <div class="col-xs-6 col-sm-12 col-md-12 nopadding">
# <div class="filter-select-div">
# <div class="filter-title">Launch Price Min</div>
# <select class="form-control" id="lprice_min" name="lprice_min"><option value="">Select Min</option><option value="0">RM 0</option>
# <option value="100000">RM 100k</option>
# <option value="200000">RM 200k</option>
# <option value="300000">RM 300k</option>
# <option value="400000">RM 400k</option>
# <option value="500000">RM 500k</option>
# <option value="600000">RM 600k</option>
# <option value="800000">RM 800k</option>
# <option value="1000000">RM 1m</option>
# <option value="1500000">RM 1.5m</option>
# <option value="2000000">RM 2m</option>
# <option value="3000000">RM 3m</option></select>
# </div>
# </div>
# <div class="col-xs-6 col-sm-12 col-md-12 nopadding">
# <div class="filter-select-div">
# <div class="filter-title">Launch Price Max</div>
# <select class="form-control" id="lprice_max" name="lprice_max"><option value="">Select Max</option><option value="100000">RM 100k</option>
# <option value="200000">RM 200k</option>
# <option value="300000">RM 300k</option>
# <option value="400000">RM 400k</option>
# <option value="500000">RM 500k</option>
# <option value="600000">RM 600k</option>
# <option value="800000">RM 800k</option>
# <option value="1000000">RM 1m</option>
# <option value="1500000">RM 1.5m</option>
# <option value="2000000">RM 2m</option>
# <option value="3000000">RM 3m</option>
# <option value="99000000">Above RM 3m</option></select>
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-4 col-md-4">
# <div class="col-xs-6 col-sm-12 col-md-12 nopadding">
# <div class="filter-select-div">
# <div class="filter-title">Subsale Price Min</div>
# <select class="form-control" id="sprice_min" name="sprice_min"><option value="">Select Min</option><option value="0">RM 0</option>
# <option value="100000">RM 100k</option>
# <option value="200000">RM 200k</option>
# <option value="300000">RM 300k</option>
# <option value="400000">RM 400k</option>
# <option value="500000">RM 500k</option>
# <option value="600000">RM 600k</option>
# <option value="800000">RM 800k</option>
# <option value="1000000">RM 1m</option>
# <option value="1500000">RM 1.5m</option>
# <option value="2000000">RM 2m</option>
# <option value="3000000">RM 3m</option></select>
# </div>
# </div>
# <div class="col-xs-6 col-sm-12 col-md-12 nopadding">
# <div class="filter-select-div">
# <div class="filter-title">Subsale Price Max</div>
# <select class="form-control" id="sprice_max" name="sprice_max"><option value="">Select Max</option><option value="100000">RM 100k</option>
# <option value="200000">RM 200k</option>
# <option value="300000">RM 300k</option>
# <option value="400000">RM 400k</option>
# <option value="500000">RM 500k</option>
# <option value="600000">RM 600k</option>
# <option value="800000">RM 800k</option>
# <option value="1000000">RM 1m</option>
# <option value="1500000">RM 1.5m</option>
# <option value="2000000">RM 2m</option>
# <option value="3000000">RM 3m</option>
# <option value="99000000">Above RM 3m</option></select>
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-4 col-md-4">
# <div class="col-xs-6 col-sm-12 col-md-12 nopadding">
# <div class="filter-select-div">
# <div class="filter-title">Build-Up / Size Min</div>
# <select class="form-control" id="size_min" name="size_min"><option value="">Select Min</option><option value="0">0 sq ft</option>
# <option value="100">100 sq ft</option>
# <option value="300">300 sq ft</option>
# <option value="500">500 sq ft</option>
# <option value="700">700 sq ft</option>
# <option value="900">900 sq ft</option>
# <option value="1200">1.2k sq ft</option>
# <option value="1500">1.5k sq ft</option>
# <option value="2000">2k sq ft</option>
# <option value="5000">5k sq ft</option>
# <option value="10000">10k sq ft</option>
# <option value="20000">20k sq ft</option></select>
# </div>
# </div>
# <div class="col-xs-6 col-sm-12 col-md-12 nopadding">
# <div class="filter-select-div">
# <div class="filter-title">Build-Up / Size Max</div>
# <select class="form-control" id="size_max" name="size_max"><option value="">Select Max</option><option value="100">100 sq ft</option>
# <option value="300">300 sq ft</option>
# <option value="500">500 sq ft</option>
# <option value="700">700 sq ft</option>
# <option value="900">900 sq ft</option>
# <option value="1200">1.2k sq ft</option>
# <option value="1500">1.5k sq ft</option>
# <option value="2000">2k sq ft</option>
# <option value="5000">5k sq ft</option>
# <option value="10000">10k sq ft</option>
# <option value="20000">20k sq ft</option>
# <option value="999999">Above 20k sq ft </option></select>
# </div>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="col-xs-12 col-sm-12 col-md-12 nopadding filter-single-div">
# <div class="col-xs-12 col-sm-4 col-md-4">
# <div class="filter-title">Accessibility</div>
# <label class="checkbox-inline">
# <input id="accessibility" name="accessibility" type="checkbox" value="true"/>
#       Near LRT / MRT / BRT / KTM
#     </label>
# </div>
# <div class="col-xs-12 col-sm-4 col-md-4">
# <div class="filter-title">Parking</div>
# <label class="checkbox-inline">
# <input id="parking_" name="parking[]" type="checkbox" value="true"/>
#       Included
#     </label>
# <label class="checkbox-inline">
# <input id="parking_" name="parking[]" type="checkbox" value="false"/>
#       Not Included
#     </label>
# </div>
# <div class="col-xs-6 col-sm-2 col-md-2">
# <div class="filter-title">Pet Friendly</div>
# <label class="checkbox-inline">
# <input id="pet_" name="pet[]" type="checkbox" value="true"/>
#       Yes
#     </label>
# <label class="checkbox-inline">
# <input id="pet_" name="pet[]" type="checkbox" value="false"/>
#       No
#     </label>
# </div>
# <div class="col-xs-6 col-sm-2 col-md-2">
# <div class="filter-title">Eco Friendly</div>
# <label class="checkbox-inline">
# <input id="eco_" name="eco[]" type="checkbox" value="true"/>
#       Yes
#     </label>
# <label class="checkbox-inline">
# <input id="eco_" name="eco[]" type="checkbox" value="false"/>
#       No
#     </label>
# </div>
# <div class="col-xs-12 col-sm-4 col-md-4">
# <div class="filter-title">Security</div>
# <label class="checkbox-inline">
# <input id="security_" name="security[]" type="checkbox" value="0"/>
#       Gated &amp; Guarded
#     </label>
# <label class="checkbox-inline">
# <input id="security_" name="security[]" type="checkbox" value="1"/>
#       24-hour
#     </label>
# </div>
# <div class="col-xs-12 col-sm-4 col-md-4">
# <div class="filter-title">Type</div>
# <label class="radio-inline">
# <input id="ctype_upcoming" name="ctype" type="radio" value="upcoming"/>
#       Upcoming
#     </label>
# <label class="radio-inline">
# <input id="ctype_completed" name="ctype" type="radio" value="completed"/>
#       Completed
#     </label>
# <label class="radio-inline">
# <input id="ctype_all" name="ctype" type="radio" value="all"/>
#       All
#     </label>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="col-xs-12 col-sm-12 col-md-12 nopadding filter-single-div">
# <div class="col-xs-6 col-sm-3 col-md-3">
# <div class="filter-title">Traffic</div>
# <div class="star-rating rating-xs rating-active fs16">
# <input class="rating form-control" data-max="5" data-min="0" data-size="xs" data-step="1" id="rating_rtraffic" name="rtraffic" style="display: none;" type="number"/>
# </div>
# </div>
# <div class="col-xs-6 col-sm-3 col-md-3">
# <div class="filter-title">Cleanliness</div>
# <div class="star-rating rating-xs rating-active fs16">
# <input class="rating form-control" data-max="5" data-min="0" data-size="xs" data-step="1" id="rating_rclean" name="rclean" style="display: none;" type="number"/>
# </div>
# </div>
# <div class="col-xs-6 col-sm-3 col-md-3">
# <div class="filter-title">Safety</div>
# <div class="star-rating rating-xs rating-active fs16">
# <input class="rating form-control" data-max="5" data-min="0" data-size="xs" data-step="1" id="rating_rsafe" name="rsafe" style="display: none;" type="number"/>
# </div>
# </div>
# <div class="col-xs-6 col-sm-3 col-md-3">
# <div class="filter-title">Quietness</div>
# <div class="star-rating rating-xs rating-active fs16">
# <input class="rating form-control" data-max="5" data-min="0" data-size="xs" data-step="1" id="rating_rquiet" name="rquiet" style="display: none;" type="number"/>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="col-xs-12 col-sm-12 col-md-12 nopadding filter-single-div search-div">
# <button class="btn btn-lightblue no-shadow" name="button" type="submit">
#           Perform Your Search Now   <i class="fa fa-search white"></i>
# </button> <br/>
# <a class="inner-trigger-advance-search-link" href="#">
#           Hide Filters  <i class="fa fa-times"></i>
# </a>        |
#         <a class="inner-trigger-reset-search-link grey" href="#">
#           Reset Filters <i class="fa fa-refresh"></i>
# </a> </div>
# </div>
# <div class="clearfix"></div>
# </section>
# <input id="tag_type" name="tag_type" type="hidden" value="Location"/>
# <input id="tag_id" name="tag_id" type="hidden" value="1"/>
# </div>
# </form> </div>
# </section>
# <!-- Overlay Navigation -->
# <section id="overlay-navigations">
# <div class="wrap">
# <div class="col-xs-12 col-sm-12 col-md-12 nopadding header">
# <div class="title">
# <i class="fa fa-search"></i>  Discover Malaysia
#         <i class="fa fa-times pull-right" id="close-overlay-link"></i>
# </div>
# </div>
# <div class="col-xs-12 col-sm-12 col-md-12 nopadding content">
# <a href="/location/1/malaysia">
# <div class="col-xs-12 col-sm-12 col-md-12 nopadding navigation-list-link">
# <div class="col-xs-12 col-sm-2 col-md-3 txt-align-center">
# <span class="icon-marker"></span>
# </div>
# <div class="col-xs-12 col-sm-10 col-md-9">
# <div class="navigation-title">Malaysia</div>
# <div class="navigation-info">
# <p>
#                 Come and discover Malaysia
#                and learn about the life, malls, and people in the area. Find out more about the schools and properties that are available here.
#             </p>
# </div>
# </div>
# </div>
# </a> <div class="clearfix"></div>
# <a href="/malaysia/1/properties?ctype=all">
# <div class="col-xs-12 col-sm-12 col-md-12 nopadding navigation-list-link">
# <div class="col-xs-12 col-sm-2 col-md-3 txt-align-center">
# <span class="ico-neighbourhood"></span>
# </div>
# <div class="col-xs-12 col-sm-10 col-md-9">
# <div class="navigation-title">
#               Properties Within Neighbourhood
#             </div>
# <div class="navigation-info">
# <p>
#               Explore the properties offered within Malaysia. You may find something suitable, be it for your own stay or as an investment.
#             </p>
# </div>
# </div>
# </div>
# </a> <div class="clearfix"></div>
# <a href="/location/1/malaysia/property-agents">
# <div class="col-xs-12 col-sm-12 col-md-12 nopadding navigation-list-link">
# <div class="col-xs-12 col-sm-2 col-md-3 txt-align-center">
# <span class="ico-agent"></span>
# </div>
# <div class="col-xs-12 col-sm-10 col-md-9">
# <div class="navigation-title">Find Area Specialist</div>
# <div class="navigation-info">
# <p>
#                 Get a Malaysia specialist to answer your enquiries and help you find your perfect home!
#               </p>
# </div>
# </div>
# </div>
# </a> <div class="clearfix"></div>
# </div>
# </div>
# </section>
# <!-- <div id="side-overlay-btn">
#   <div class='more-navigations-link'>
#     <i class="fa fa-search"></i>
#     <span class="link-name">Discover More</span>
#   </div>
# </div> -->
# <!-- Breadcrumb -->
# <section id="breadcrumb">
# <div class="wrap">
# <div id="navigation-levels">
#       Malaysia <i class="fa fa-angle-right"></i> <span class="current">Malaysia</span>
# <!-- <span id="more-navigations">
#         <a class="pull-right more-navigations-link wow hvr-grow swing" data-wow-delay="1s" href="#">
#           Discover More
#           <i class="fa fa-search"></i>
# </a>      </span> -->
# <div class="clearfix"></div>
# </div>
# </div>
# </section>
# <section id="search-results">
# <div class="wrap">
# <div class="row">
# <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12 listing-result-headline">
# <div class="col-lg-8 col-md-8 col-sm-12 col-xs-12 nopadding">
# <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12 nopadding">
# <h1>
#                   Properties For Sale in Malaysia
#               </h1>
# </div>
# <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12 nopadding">
# <h2>showing 99,633 properties For Sale in Malaysia
#               </h2>
# </div>
# <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12 nopadding pdb2">
# <ul class="nav nav-pills ad-header-filters">
# <li class="active" role="presentation"><a href="#">All</a></li>
# <li class="" role="presentation">
# <a href="/buy/malaysia-1?new=true&amp;page=339" rel="nofollow">
# ...
# </li>
# <li>
# <a href="/buy/cheras-37/upcoming-developments" onclick="trackOutboundLink('/buy/cheras-37/upcoming-developments');" title="All Upcoming Properties in Cheras">New Properties in Cheras</a>
# </li>
# <li>
# <a href="/buy/klang-198/upcoming-developments" onclick="trackOutboundLink('/buy/klang-198/upcoming-developments');" title="All Upcoming Properties in Klang">New Properties in Klang</a>
# </li>
# <li>
# <a href="/buy/mont-kiara-67/upcoming-developments" onclick="trackOutboundLink('/buy/mont-kiara-67/upcoming-developments');" title="All Upcoming Properties in Mont Kiara">New Properties in Mont Kiara</a>
# </li>
# </div>
# <li>
# <a href="javascript:;" id="footer-view-more-prop-btn" style="color: #e44444; font-weight: 500 !important;">View more</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-sm-3">
# <div class="footer-header" style="font-size: 14px !important;">
# <a href="/" style="color: #1f98af !important;">PropSocial</a>
# </div>
# <div class="col-sm-12">
# <ul class="footer-list">
# <li>
# <a href="/faq" onclick="trackOutboundLink('https://www.propsocial.my/faq');" title="FAQ of PropSocial">FAQ</a>
# </li>
# <li>
# <a href="/terms-of-use" onclick="trackOutboundLink('https://www.propsocial.my/terms-of-use');" title="Term Of Use on Propsocial">Terms Of Use</a>
# </li>
# <li>
# <a href="/about-us" onclick="trackOutboundLink('https://www.propsocial.my/about-us');" title="About Us on Propsocial">About Us</a>
# </li>
# <li>
# <a href="/contact" onclick="trackOutboundLink('https://www.propsocial.my/contact');" title="Contact Us on Propsocial">Contact Us</a>
# </li>
# <li>
# <a href="/discussions/editors_choice" onclick="trackOutboundLink('https://www.propsocial.my/discussions/top');" title="Top discussions about property related topics">Latest News Discussions</a>
# </li>
# <div id="footer-view-more-propsocial-div" style="display: none;">
# <li>
# <a href="/location/33/kuala-lumpur/property-agents" onclick="trackOutboundLink('/location/33/kuala-lumpur/property-agents');" title="Kuala Lumpur / KL Agents">Kuala Lumpur / KL Agents</a>
# </li>
# <li>
# <a href="/location/203/petaling-jaya/property-agents" onclick="trackOutboundLink('/location/203/petaling-jaya/property-agents');" title="Petaling Jaya / PJ Agents">Petaling Jaya / PJ Agents</a>
# </li>
# <li>
# <a href="/location/219/puchong/property-agents" onclick="trackOutboundLink('/location/219/puchong/property-agents');" title="Puchong Agents">Puchong Agents</a>
# </li>
# <li>
# <a href="/location/67/mont-kiara/property-agents" onclick="trackOutboundLink('/location/67/mont-kiara/property-agents');" title="Mont Kiara Agents">Mont Kiara Agents</a>
# </li>
# <li>
# <a href="/location/248/subang-jaya/property-agents" onclick="trackOutboundLink('/location/248/subang-jaya/property-agents');" title="Subang Jaya Agents">Subang Jaya Agents</a>
# </li>
# <li>
# <a href="/discussions" onclick="trackOutboundLink('https://www.propsocial.my/discussions');" title="Latest discussions about property related topics">Latest Forum Discussions</a>
# </li>
# <li>
# <a href="/property/post-requirements?utm_campaign=pr&amp;utm_medium=header&amp;utm_source=propsocial" onclick="trackOutboundLink('https://www.propsocial.my/property/post-requirements?utm_campaign=pr&amp;utm_medium=header&amp;utm_source=propsocial');" title="Post Property Requirements to find home">Post Requirements</a>
# </li>
# <li>
# <a href="/users/sign_up?category=agent" onclick="trackOutboundLink('https://www.propsocial.my/users/sign_up?category=agent');" title="Register As An Agent">Register As An Agent</a>
# </li>
# <li>
# <a href="/signup" onclick="trackOutboundLink('https://www.propsocial.my/signup');" title="Register As A User">Register As A User</a>
# </li>
# </div>
# <li>
# <a href="javascript:;" id="footer-view-more-propsocial-btn" style="color: #e44444; font-weight: 500 !important;">View more</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-sm-12" style="padding-bottom: 30px;">
# <div class="col-sm-6">
# <img alt="PropSocial Footer logo" data-original="https://d19b02hn5tml7l.cloudfront.net/assets/logo-22e629a1032f1a52db65d2dd79493852.png" src="/public_assets/images/transparent.png" style="max-width: 220px; max-height: 27px;"/>
# <p class="propsocial-company-description">
#           PropSocial is the first <b>property website</b> in Malaysia to <b>feature honest reviews</b> direct from the community, with an easy-to-use interface that will help users find their ideal property within minutes. We provide real feedback directly from end users on properties and neighbourhoods to help property buyer make better decisions in their property-buying process by providing non-biased recommendations.
#
#           <br/>
# <i class="fa fa-envelope"></i>
# <span class="support-email">
# <a href="/contact" onclick="trackOutboundLink('https://www.propsocial.my/contact');" title="Contact Us">support@propsocial.com</a>
# </span>
# </p>
# </div>
# <div class="col-sm-3">
onclick="trackOutboundLink(/buy/malaysia/malaysia-1/soho-studio);">Sale</a>
# </li>
# <li>
#                 Townhouse for
#                 <a href="/rent/malaysia/malaysia-1/townhouse" onclick="trackOutboundLink(/rent/malaysia/malaysia-1/townhouse);">Rent</a> /
#                 <a href="/buy/malaysia/malaysia-1/townhouse" onclick="trackOutboundLink(/buy/malaysia/malaysia-1/townhouse);">Sale</a>
# </li>
# <li>
#                 Terrace for
#                 <a href="/rent/malaysia/malaysia-1/terrace" onclick="trackOutboundLink(/rent/malaysia/malaysia-1/terrace);">Rent</a> /
#                 <a href="/buy/malaysia/malaysia-1/terrace" onclick="trackOutboundLink(/buy/malaysia/malaysia-1/terrace);">Sale</a>
# </li>
# <li>
#                 Bungalow for
#                 <a href="/rent/malaysia/malaysia-1/bungalow" onclick="trackOutboundLink(/rent/malaysia/malaysia-1/bungalow);">Rent</a> /
#                 <a href="/buy/malaysia/malaysia-1/bungalow" onclick="trackOutboundLink(/buy/malaysia/malaysia-1/bungalow);">Sale</a>
# </li>
# <li>
#                 Semi-Detached for
#                 <a href="/rent/malaysia/malaysia-1/semi-detached" onclick="trackOutboundLink(/rent/malaysia/malaysia-1/semi-detached);">Rent</a> /
#                 <a href="/buy/malaysia/malaysia-1/semi-detached" onclick="trackOutboundLink(/buy/malaysia/malaysia-1/semi-detached);">Sale</a>
# </li>
# <li>
#                 Office for
#                 <a href="/rent/malaysia/malaysia-1/office" onclick="trackOutboundLink(/rent/malaysia/malaysia-1/office);">Rent</a> /
#                 <a href="/buy/malaysia/malaysia-1/office" onclick="trackOutboundLink(/buy/malaysia/malaysia-1/office);">Sale</a>
# </li>
# </div>
# <li>
# <a href="javascript:;" id="footer-view-more-discover-btn" style="color: #e44444; font-weight: 500 !important;">View more</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-md-6 col-sm-8">
# <div class="col-sm-6">
# <div class="footer-header" style="font-size: 14px !important;">
#           Follow Us On
#         </div>
# <div class="col-sm-12">
# <ul class="connect-social">
# <li>
# <a href="https://www.facebook.com/propsocial.my/" onclick="trackOutboundLink('https://www.facebook.com/propsocial.my/');" target="_blank" title="Propsocial on Facebook">
# <span class="fa-stack fa-lg hvr-grow">
# <i class="fa fa-circle fa-stack-2x facebook"></i>
# <i class="fa fa-facebook fa-stack-1x"></i>
# </span>
# </a> </li>
# <li>
# <a href="https://www.instagram.com/propsocial.my/" onclick="trackOutboundLink('https://www.instagram.com/propsocial.my/');" target="_blank" title="Propsocial on Instagram">
# <span class="fa-stack fa-lg hvr-grow">
# <i class="fa fa-circle fa-stack-2x instagram"></i>
# <i class="fa fa-instagram fa-stack-1x"></i>
# </span>
# </a> </li>
# <li>
# <a href="https://twitter.com/propsocial_my" onclick="trackOutboundLink('https://twitter.com/propsocial_my');" target="_blank" title="Propsocial on Twitter">
# <span class="fa-stack fa-lg hvr-grow">
# <i class="fa fa-circle fa-stack-2x twitter"></i>
# <i class="fa fa-twitter fa-stack-1x"></i>
# </span>
# </a> </li>
# <li>
# <a href="https://www.linkedin.com/company/propsocial.my" onclick="trackOutboundLink('https://www.linkedin.com/company/propsocial.my');" target="_blank" title="Propsocial on LinkedIn">
# <span class="fa-stack fa-lg hvr-grow">
# <i class="fa fa-circle fa-stack-2x linkedin"></i>
# <i class="fa fa-linkedin fa-stack-1x"></i>
# </span>
# </a> </li>
# <li>
# <a href="https://www.youtube.com/channel/UCCHXi0hs5iJbAFkf9ez8wHA" onclick="trackOutboundLink('https://www.youtube.com/channel/UCCHXi0hs5iJbAFkf9ez8wHA');" target="_blank" title="Propsocial on Youtube">
# <span class="fa-stack fa-lg hvr-grow">
# <i class="fa fa-circle fa-stack-2x youtube"></i>
# <i class="fa fa-youtube fa-stack-1x"></i>
# </span>
# </a> </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-md-3">
#