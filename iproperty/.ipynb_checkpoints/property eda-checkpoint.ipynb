# %%
import pandas as pd

import geopandas as gpd
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('1to115.csv')
df
# Out:
#       Unnamed: 0                                               link  \
# 0              0  https://www.propsocial.my/developments/bk2/ter...
# 1              1  https://www.propsocial.my/developments/section...
# 2              2  https://www.propsocial.my/developments/taman-s...
# 3              3                  /developments/uno-promenade-10536
# 4              4  https://www.propsocial.my/developments/casa-re...
# ...          ...                                                ...
# 1867        1867  https://www.propsocial.my/developments/taman-s...
# 1868        1868                /developments/edence-florence-11016
# 1869        1869  https://www.propsocial.my/developments/8th-ste...
# 1870        1870  https://www.propsocial.my/developments/jalan-t...
# 1871        1871  https://www.propsocial.my/developments/contine...
#
#                                         title  \
# 0                        BK2, Bandar Kinrara
# 1           Section 6, Bandar Mahkota Cheras
# 2                  Taman Sri Manja, PJ South
# 3                              UNO Promenade
# 4      Casa Residence, Bandar Mahkota Cheras
# ...                                       ...
# 1867                   Taman Sejati 5, Klang
# 1868                       Edence & Florence
# 1869             8th & Stellar, Sri Petaling
# 1870       Jalan Tunku Abdul Rahman, Kuching
# 1871                          Continew, Pudu
#
#                                                  detail
# 0     [' Freehold ', ' Terrace ', ' 2,000 SQ. FT ', ...
# 1     [' Freehold ', ' Terrace ', ' 1,888 SQ. FT ', ...
# 2     [' Freehold ', ' Condominium ', ' 1,138 SQ. FT...
# 3     [' Leasehold ', ' Serviced Residence ', ' 1,10...
# 4     [' Freehold ', ' Semi Detached ', ' 3,615 SQ. ...
# ...                                                 ...
# 1867  [' Freehold ', ' Terrace ', ' 1,400 SQ. FT ', ...
# 1868  [' Freehold ', ' Semi Detached ', ' Sqf not sp...
# 1869  [' Leasehold ', ' Condominium ', ' 1,300 SQ. F...
# 1870  [' Freehold ', ' So Ho/Studio ', ' 1 SQ. FT ',...
# 1871  [' Freehold ', ' Condominium ', ' 554 SQ. FT '...
#
# [1872 rows x 4 columns]

# %%
locator = Nominatim(user_agent="myGeocoder")

# 1 - conveneint function to delay between geocoding calls
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)
# 2- - create location column
df['location'] = df['title'].apply(geocode)
# 3 - create longitude, laatitude and altitude from location column (returns tuple)
df['point'] = df['location'].apply(lambda loc: tuple(loc.point) if loc else None)
# 4 - split point column into latitude, longitude and altitude columns
df[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df['point'].tolist(), index=df.index)

# %%
df
# Out:
#       Unnamed: 0                                               link  \
# 0              0  https://www.propsocial.my/developments/bk2/ter...
# 1              1  https://www.propsocial.my/developments/section...
# 2              2  https://www.propsocial.my/developments/taman-s...
# 3              3                  /developments/uno-promenade-10536
# 4              4  https://www.propsocial.my/developments/casa-re...
# ...          ...                                                ...
# 1867        1867  https://www.propsocial.my/developments/taman-s...
# 1868        1868                /developments/edence-florence-11016
# 1869        1869  https://www.propsocial.my/developments/8th-ste...
# 1870        1870  https://www.propsocial.my/developments/jalan-t...
# 1871        1871  https://www.propsocial.my/developments/contine...
#
#                                         title  \
# 0                        BK2, Bandar Kinrara
# 1           Section 6, Bandar Mahkota Cheras
# 2                  Taman Sri Manja, PJ South
# 3                              UNO Promenade
# 4      Casa Residence, Bandar Mahkota Cheras
# ...                                       ...
# 1867                   Taman Sejati 5, Klang
# 1868                       Edence & Florence
# 1869             8th & Stellar, Sri Petaling
# 1870       Jalan Tunku Abdul Rahman, Kuching
# 1871                          Continew, Pudu
#
#                                                  detail  \
# 0     [' Freehold ', ' Terrace ', ' 2,000 SQ. FT ', ...
# 1     [' Freehold ', ' Terrace ', ' 1,888 SQ. FT ', ...
# 2     [' Freehold ', ' Condominium ', ' 1,138 SQ. FT...
# 3     [' Leasehold ', ' Serviced Residence ', ' 1,10...
# 4     [' Freehold ', ' Semi Detached ', ' 3,615 SQ. ...
# ...                                                 ...
# 1867  [' Freehold ', ' Terrace ', ' 1,400 SQ. FT ', ...
# 1868  [' Freehold ', ' Semi Detached ', ' Sqf not sp...
# 1869  [' Leasehold ', ' Condominium ', ' 1,300 SQ. F...
# 1870  [' Freehold ', ' So Ho/Studio ', ' 1 SQ. FT ',...
# 1871  [' Freehold ', ' Condominium ', ' 554 SQ. FT '...
#
#                                                location  \
# 0     (Bandar Kinrara, Puchong, Selangor, 47100, Mal...
# 1     (BMC Section 9 Park 1, Bandar Mahkota Cheras, ...
# 2     (Taman Sri Manja, Petaling Jaya, Selangor, 460...
# 3                                                  None
# 4     (Bandar Mahkota Cheras, Majlis Perbandaran Kaj...
# ...                                                 ...
# 1867                                               None
# 1868                                               None
# 1869                                               None
# 1870  (Jalan Tunku Abdul Rahman, Petra Jaya, Kuching...
# 1871                                               None
#
#                                       point  latitude   longitude  altitude
# 0             (3.0447358, 101.6405794, 0.0)  3.044736  101.640579       0.0
# 1     (3.05859565, 101.78843152118904, 0.0)  3.058596  101.788432       0.0
# 2             (3.0738997, 101.6455165, 0.0)  3.073900  101.645516       0.0
# 3                                      None       NaN         NaN       NaN
# 4             (3.0568568, 101.7898004, 0.0)  3.056857  101.789800       0.0
# ...                                     ...       ...         ...       ...
# 1867                                   None       NaN         NaN       NaN
# 1868                                   None       NaN         NaN       NaN
# 1869                                   None       NaN         NaN       NaN
# 1870          (1.5580558, 110.3507149, 0.0)  1.558056  110.350715       0.0
# 1871                                   None       NaN         NaN       NaN
#
# [1872 rows x 9 columns]

# %%
df.to_csv('propsocial_test_geo.csv')
